# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
#loop through each of the 276 pages of reviews
for i in range(1, 10):
    url = "https://www.trustpilot.com/review/www.mcmakler-finance.de?languages=de&page={}".format(i)
    result = requests.get(url)
    soup = BeautifulSoup(result.content)
    reviews = soup.find_all('article', class_='review')
    for review in reviews:
 
        allUsers.append(review('aside')[0]('a')[0]('div', 
        class_='consumer-information__details')[0]('div',  
        class_='consumer-information__name')[0].string)
        #convert dictionary outputted as a string to a Python 
        Dictionary using json module
        ratingsDic = json.loads(review('script')[0].string)
        allRatings.append(ratingsDic['stars'])
        if(not(review('aside')[0]('a')[0]('div', class_='consumer-  
        information__details')[0]('div', class_='consumer- 
        information__data')[0]('div', class_='consumer-
        information__location')) == []):
            allLocations.append(review('aside')[0]('a')[0]('div', 
            class_='consumer-information__details')[0]('div', 
            class_='consumer-information__data')[0]('div',    
            class_='consumer-information__location')[0]('span')
            [0].string)
        else:
         allLocations.append("")
        datesDic = json.loads(review('div', class_='review-content-
        header__dates')[0]('script')[0].string)
        allDates.append(datesDic['publishedDate'])
        reviewDic = json.loads(review('script')[0].string)
        allReviewContent.append(reviewDic['reviewHeader'])
# Out:
#   File "/var/folders/gg/ydzntksx7jl3t92y3_bqsw140000gn/T/ipykernel_67318/1872442872.py", line 13
#     Dictionary using json module
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### New Test

# %%
url = "https://www.trustpilot.com/review/www.mcmakler-finance.de?languages=de&page=1"
test = requests.get(url)
soup = BeautifulSoup(test.text, 'html.parser')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en-US"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="/manifest.json" rel="manifest"/><meta content="Trustpilot" name="application-name"/><meta content="#000032" name="theme-color"/><link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link color="#00b67a" href="https://cdn.trustpilot.net/brand-assets/1.9.0/favicons/safari-pinned-tab.svg" rel="mask-icon"/><meta content="Trustpilot" name="apple-mobile-web-app-title"/><meta content="#000032" name="msapplication-TileColor"/><meta content="https://businessunitprofile-cdn.trustpilot.net/assets/browserconfig.xml" name="msapplication-config"/><script>
#                 (function() { /* 'Disable' Segments Querystring API */
#                     var os = location.search;
#                     var ns = os.length ? '?'+os.substring(1).split('&').filter(function(param){return !/^ajs_(aid|event|uid)=/i.test(param);}).join('&') : '';
#                     if (typeof window.history === 'object' && os !== ns) {
#                         window.history.replaceState({}, '', location.pathname + ns)
#                     }
#                 })();
#                 !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t,e){var n=document.createElement("script");n.type="text/plain";n.classList.add("optanon-category-C0002");n.async=!0;n.src="https://cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(n,a);analytics._loadOptions=e};
#                 analytics.SNIPPET_VERSION="4.1.0";
#                 analytics.load("8tb69qtawc");
#                 }}();
#             </script><script type="text/javascript">
#               _atrk_opts = { atrk_acct: "uIxpk1a0Sn00yT", domain: "trustpilot.com", dynamic: false };
#               (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#             </script><script>
#             (function(h){
#                 h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#                 h._hjSettings={hjid:391767,hjsv:6};
#             })(window);
#           </script><script class="optanon-category-C0002" src="https://static.hotjar.com/c/hotjar-391767.js?sv=6" type="text/plain"></script><script defer="" nomodule="" src="https://polyfills.trustpilot.com/v2/polyfill.min.js?features=Promise,fetch,Object.assign,Element.prototype.matches,Element.prototype.closest&amp;flags=gated"></script><link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/><link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/><link crossorigin="" href="https://user-images.trustpilot.com/" rel="preconnect"/><link href="https://cdn.segment.com/analytics.js/v1/8tb69qtawc/analytics.min.js" rel="prefetch"/><link href="https://static.hotjar.com/c/hotjar-391767.js?sv=6" rel="prefetch"/><link crossorigin="" href="https://cdn.cookielaw.org" rel="preconnect"/><link crossorigin="" href="https://geolocation.onetrust.com" rel="preconnect"/><script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript"></script><script>
#           function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#           }</script><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><title>McMakler Finance Reviews | Read Customer Service Reviews of www.mcmakler-finance.de</title><meta content="Do you agree with McMakler Finance's star rating? Check out what 191 people have written so far, and share your own experience." name="description"/><link href="https://www.trustpilot.com/review/www.mcmakler-finance.de" rel="canonical"/><link href="https://at.trustpilot.com/review/www.mcmakler-finance.de" hreflang="de-AT" rel="alternate"/><link href="https://ch.trustpilot.com/review/www.mcmakler-finance.de" hreflang="de-CH" rel="alternate"/><link href="https://de.trustpilot.com/review/www.mcmakler-finance.de" hreflang="de" rel="alternate"/><link href="https://au.trustpilot.com/review/www.mcmakler-finance.de" hreflang="en-AU" rel="alternate"/><link href="https://ca.trustpilot.com/review/www.mcmakler-finance.de" hreflang="en-CA" rel="alternate"/><link href="https://uk.trustpilot.com/review/www.mcmakler-finance.de" hreflang="en-GB" rel="alternate"/><link href="https://ie.trustpilot.com/review/www.mcmakler-finance.de" hreflang="en-IE" rel="alternate"/><link href="https://nz.trustpilot.com/review/www.mcmakler-finance.de" hreflang="en-NZ" rel="alternate"/><link href="https://www.trustpilot.com/review/www.mcmakler-finance.de" hreflang="x-default" rel="alternate"/><link href="https://www.trustpilot.com/review/www.mcmakler-finance.de" hreflang="en" rel="alternate"/><meta content='McMakler Finance is rated "Excellent" with 4.6 / 5 on Trustpilot' property="og:title"/><meta content="trustpilot:company" property="og:type"/><meta content="https://www.trustpilot.com/review/www.mcmakler-finance.de" property="og:url"/><meta content="Trustpilot" property="og:site_name"/><meta content="Do you agree with McMakler Finance's TrustScore? Voice your opinion today and hear what 191 customers have already said." property="og:description"/><meta content="https://share.trustpilot.com/images/company-rating?locale=en-US&amp;businessUnitId=5dd5036125e0ee000163d1a8&amp;preset=consumersite" property="og:image"/><meta content="1080" property="og:image:width"/><meta content="1080" property="og:image:height"/><meta content="en_US" property="og:locale"/><meta content="65206056824" property="fb:app_id"/><meta content="https://share.trustpilot.com/images/company-rating?locale=en-US&amp;businessUnitId=5dd5036125e0ee000163d1a8" name="twitter:image"/><meta content="summary_large_image" name="twitter:card"/><meta content="@Trustpilot" name="twitter:site"/><meta content='McMakler Finance is rated "Excellent" with 4.6 / 5 on Trustpilot' name="twitter:title"/><meta content="Do you agree with McMakler Finance's TrustScore? Voice your opinion today and hear what 191 customers have already said." name="twitter:description"/><meta content="max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/><script data-business-unit-json-ld="true" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.trustpilot.com/#/schema/Organization/1","name":"Trustpilot","legalName":"Trustpilot A/S","url":"https://www.trustpilot.com","description":"Read reviews. Write reviews. Find companies.","sameAs":["https://en.wikipedia.org/wiki/Trustpilot","https://www.facebook.com/Trustpilot/","https://www.instagram.com/trustpilot/","https://www.linkedin.com/company/trustpilot","https://twitter.com/Trustpilot","https://www.youtube.com/c/trustpilotreviews"],"logo":{"@id":"https://www.trustpilot.com/#/schema/ImageObject/Logo/1"},"founder":{"@id":"https://www.trustpilot.com/#/schema/Person/Peter_Holten_Mühlmann"},"foundingDate":"2007","email":"support@trustpilot.com","address":{"@type":"PostalAddress","@id":"https://www.trustpilot.com/#/schema/PostalAddress/DK","streetAddress":"Pilestræde 58, 5th floor","addressLocality":"Copenhagen","addressCountry":"DK","postalCode":"1112 København"},"contactPoint":[{"@type":"ContactPoint","@i ...

# %%
reviews = soup.find_all('script', type="application/ld+json")

# %%
m=reviews[0].get_text()

# %%
# GET FEEDBACK CONTENT

ptags = soup.select('div > p')

revlist = []

for p in ptags:
    revlist.append(p.get_text())
    
revlist=revlist[6:(len(revlist)-5)]

review_df = pd.DataFrame({"text":revlist})
display(review_df)
# Out:
#                                                 text
# 0  Berkant Ercin- very good Finanzier for arrangi...
# 1  I would like to extend my sincere gratitude an...
# 2  Gregor Knuth hat mich in dieser Angelegenheit ...
# 3                               100% happy with them
# 4  Great experience by Berkant! He was very activ...
# 5  I had a good experience with the McMakler team...

# %%
# Get Names of Reviewers

nametags= soup.select('article > aside > div > a > div:first-child')

namelist = []

for n in nametags:
    namelist.append(n.get_text())
    

review_df = pd.DataFrame({"reviewer":namelist,"text":revlist})
display(review_df)
# Out:
#         reviewer                                               text
# 0      Vinothini  Berkant Ercin- very good Finanzier for arrangi...
# 1      Raj Kumar  I would like to extend my sincere gratitude an...
# 2             LB  Gregor Knuth hat mich in dieser Angelegenheit ...
# 3         Wagner                               100% happy with them
# 4       Octavian  Great experience by Berkant! He was very activ...
# 5  Obaida Alhaji  I had a good experience with the McMakler team...

# %%
# GET REVIEW STARS
soup.find_all('div', class_="star-rating_starRating__4rrcf star-rating_medium__iN6Ty")
# Out:
# [<div class="star-rating_starRating__4rrcf star-rating_medium__iN6
.27.196a.785.785 0 0 1-.89 0 18.273 18.273 0 0 1-.947-.728 20.175 20.175 0 0 1-2.045-1.933C3.157 11.122 2 8.93 2 6.686 2 3 4.903 0 8.5 0S15 3 15 6.686c0 2.243-1.157 4.436-3.063 6.515ZM8.5 9.431c-1.491 0-2.687-1.237-2.687-2.746S7.01 3.941 8.5 3.941c1.491 0 2.687 1.236 2.687 2.745 0 1.51-1.196 2.745-2.687 2.745Zm0-1.55c.615 0 1.127-.528 1.127-1.196 0-.667-.512-1.196-1.127-1.196s-1.127.529-1.127 1.196c0 .668.512 1.197 1.127 1.197Z" fill-rule="nonzero"></path></g></g></svg><span class="typography_typography__QgicV typography_weight-inherit__iX6Fc typography_fontstyle-inherit__ly_HV" data-consumer-country-typography="true">DE</span></div></div></a></div></aside><hr class="divider_divider__M85e9 styles_cardDivider__42s_0"/><section class="styles_reviewContentwrapper__zH_9M"><div class="styles_reviewHeader__iU9Px" data-service-review-rating="5"><div class="star-rating_starRating__4rrcf star-rating_medium__iN6Ty"><img alt="Rated 5 out of 5 stars" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg"/></div><div class="typography_typography__QgicV typography_bodysmall__irytL typography_color-gray-6__TogX2 typography_weight-regular__TWEnf typography_fontstyle-normal__kHyN ...

# %% [markdown]
# # Test ganze Seite

# %%
url2 = "https://www.trustpilot.com/review/www.mcmakler-finance.de?languages=de"
test = requests.get(url2)
soup = BeautifulSoup(test.text, 'html.parser')

# %%
# GET FEEDBACK CONTENT

ptags = soup.select('div > p')

revlist = []

for p in ptags:
    revlist.append(p.get_text())
    
revlist=revlist[6:(len(revlist)-5)]

review_df = pd.DataFrame({"text":revlist})
display(review_df)

# Get Names of Reviewers

nametags= soup.select('article > aside > div > a > div:first-child')

namelist = []

for n in nametags:
    namelist.append(n.get_text())

print(namelist)    

review_df = pd.DataFrame({"reviewer":namelist,"text":revlist})
display(review_df)
# Out:
#                                                  text
# 0   Ich kann Herrn Billor zu 110% nur weiterempfeh...
# 1   Alles top, sehr gute Unterstützung und schnell...
# 2   Unser großes Lob gilt Herrn Frank Pfister, für...
# 3   Wir waren sehr zufrieden mit der Beratung zur ...
# 4   Super Service - besser geht es kaum. Sehr komp...
# 5   Sehr flexible und schnelle Bearbeitung der Anf...
# 6                         Ich bin sehr zufrieden🍷🍷🍷🍾🍾
# 7   Sehr kompetente und freundliche Frau Kihn.Bin ...
# 8   Wir benötigten innerhalb von 1 Woche für einen...
# 9   Wieder gerne. Sehr zufrieden. Besonders...  Be...
# 10  Nichts zu bemängeln.Frau Schröder ist mit sehr...
# 11  Schnelle, kompetente Lösungsvorschläge, gute H...
# 12  Ging recht schnell und unkompliziert.Ohne lang...
# 13  Hat alles bestens mit McMarkler geklappt.  Kan...
# 14  Alles im Allen begann es gut. Maklertermin gin...
# 15                  Top, gut beraten super Abwicklung
# 16  Wir wurden vom Anfang unserer Anfrage für eine...
# 17  Sehr zufriedenstellende und seriöse Bearbeitun...
# 18  Wir haben unsere Immobilie von Frau Skwarczyns...
# ['Daniel', 'Kunde', 'Familie Wendt', 'Kunde', 'Ronny B.', 'Kunde', 'Hou', 'Kunde', 'Veronika', 'Kunde', 'Andre B.', 'Käufer Eigentumswohnung', 'Kunde', 'Kunde', 'Kunde', 'Christian H.', 'Kunde', 'Eduard Brauer', 'Lohnstein Dietmar', 'Carina Becker']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gg/ydzntksx7jl3t92y3_bqsw140000gn/T/ipykernel_67318/2437145779.py in <module>
#      24 print(namelist)
#      25
# ---> 26 review_df = pd.DataFrame({"reviewer":namelist,"text":revlist})
#      27 display(review_df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
ptags = soup.select('div > p')

# %%
# GET FEEDBACK CONTENT

content=soup.find_all('div', class_="styles_reviewContent__0Q2Tg")

revlist = []   
    
for p in content:
    revlist.append(p.get_text())

review_df = pd.DataFrame({"text":revlist})
display(review_df)

# Get Names of Reviewers

nametags= soup.select('article > aside > div > a > div:first-child')

namelist = []

for n in nametags:
    namelist.append(n.get_text())

print(namelist)    

review_df = pd.DataFrame({"reviewer":namelist,"text":revlist})
display(review_df)
# Out:
#                                                  text
# 0   Ich kann Herrn Billor zu 110% nur…Ich kann Her...
# 1   Alles topAlles top, sehr gute Unterstützung un...
# 2   Unser großes Lob gilt Herrn Frank…Unser großes...
# 3   Wir waren sehr zufrieden mit der…Wir waren seh...
# 4   Super ServiceSuper Service - besser geht es ka...
# 5   Sehr flexible und schnelle Bearbeitung…Sehr fl...
# 6               Zufrieden.Ich bin sehr zufrieden🍷🍷🍷🍾🍾
# 7   Sehr kompetente und freundliche Frau…Sehr komp...
# 8   Finanzierung für ImmobilenkaufWir benötigten i...
# 9   Wieder gerneWieder gerne. Sehr zufrieden. Beso...
# 10  TOP Finanzierungs VermittlerinNichts zu bemäng...
# 11  Kompetent und kommunikativSchnelle, kompetente...
# 12  Ging recht schnell und unkompliziert.Ging rech...
# 13  Hat alles bestens mit McMarkler…Hat alles best...
# 14  Alles im Allen begann es gutAlles im Allen beg...
# 15  Top alles super gelaufenTop, gut beraten super...
# 16                                   Lief alles super
# 17  Sehr seriös und kompetentWir wurden vom Anfang...
# 18  Sehr gutes Angebot, zufriedenstellend und seri...
# 19  Super Beratung durch Frau Skwarczynski und Fra...
# ['Daniel', 'Kunde', 'Familie Wendt', 'Kunde', 'Ronny B.', 'Kunde', 'Hou', 'Kunde', 'Veronika', 'Kunde', 'Andre B.', 'Käufer Eigentumswohnung', 'Kunde', 'Kunde', 'Kunde', 'Christian H.', 'Kunde', 'Eduard Brauer', 'Lohnstein Dietmar', 'Carina Becker']
#                    reviewer                                               text
# 0                    Daniel  Ich kann Herrn Billor zu 110% nur…Ich kann Her...
# 1                     Kunde  Alles topAlles top, sehr gute Unterstützung un...
# 2             Familie Wendt  Unser großes Lob gilt Herrn Frank…Unser großes...
# 3                     Kunde  Wir waren sehr zufrieden mit der…Wir waren seh...
# 4                  Ronny B.  Super ServiceSuper Service - besser geht es ka...
# 5                     Kunde  Sehr flexible und schnelle Bearbeitung…Sehr fl...
# 6                       Hou              Zufrieden.Ich bin sehr zufrieden🍷🍷🍷🍾🍾
# 7                     Kunde  Sehr kompetente und freundliche Frau…Sehr komp...
# 8                  Veronika  Finanzierung für ImmobilenkaufWir benötigten i...
# 9                     Kunde  Wieder gerneWieder gerne. Sehr zufrieden. Beso...
# 10                 Andre B.  TOP Finanzierungs VermittlerinNichts zu bemäng...
# 11  Käufer Eigentumswohnung  Kompetent und kommunikativSchnelle, kompetente...
# 12                    Kunde  Ging recht schnell und unkompliziert.Ging rech...
# 13                    Kunde  Hat alles bestens mit McMarkler…Hat alles best...
# 14                    Kunde  Alles im Allen begann es gutAlles im Allen beg...
# 15             Christian H.  Top alles super gelaufenTop, gut beraten super...
# 16                    Kunde                                   Lief alles super
# 17            Eduard Brauer  Sehr seriös und kompetentWir wurden vom Anfang...
# 18        Lohnstein Dietmar  Sehr gutes Angebot, zufriedenstellend und seri...
# 19            Carina Becker  Super Beratung durch Frau Skwarczynski und Fra...

# %%
# Get Titles to correct content
titles = soup.select('div > h2')

titlist = []   
    
for t in titles:
    titlist.append(len(t.get_text()))
    
titlist = titlist[2:]
titlist
# Out:
# [34, 9, 34, 33, 13, 39, 10, 37, 30, 12, 30, 26, 37, 32, 28, 24, 16, 25, 50, 54]

# %%
review_df['text'].replace
# Out:
# <bound method Series.replace of 0     Ich kann Herrn Billor zu 110% nur…Ich kann Her...
# 1     Alles topAlles top, sehr gute Unterstützung un...
# 2     Unser großes Lob gilt Herrn Frank…Unser großes...
# 3     Wir waren sehr zufrieden mit der…Wir waren seh...
# 4     Super ServiceSuper Service - besser geht es ka...
# 5     Sehr flexible und schnelle Bearbeitung…Sehr fl...
# 6                 Zufrieden.Ich bin sehr zufrieden🍷🍷🍷🍾🍾
# 7     Sehr kompetente und freundliche Frau…Sehr komp...
# 8     Finanzierung für ImmobilenkaufWir benötigten i...
# 9     Wieder gerneWieder gerne. Sehr zufrieden. Beso...
# 10    TOP Finanzierungs VermittlerinNichts zu bemäng...
# 11    Kompetent und kommunikativSchnelle, kompetente...
# 12    Ging recht schnell und unkompliziert.Ging rech...
# 13    Hat alles bestens mit McMarkler…Hat alles best...
# 14    Alles im Allen begann es gutAlles im Allen beg...
# 15    Top alles super gelaufenTop, gut beraten super...
# 16                                     Lief alles super
# 17    Sehr seriös und kompetentWir wurden vom Anfang...
# 18    Sehr gutes Angebot, zufriedenstellend und seri...
# 19    Super Beratung durch Frau Skwarczynski und Fra...
# Name: text, dtype: object>

# %%
clean_content = []
for text, kill in zip(review_df['text'],titlist):
    clean_content.append(text[kill:])

# %%
review_df['text']=clean_content
review_df
# Out:
#                    reviewer  \
# 0                    Daniel
# 1                     Kunde
# 2             Familie Wendt
# 3                     Kunde
# 4                  Ronny B.
# 5                     Kunde
# 6                       Hou
# 7                     Kunde
# 8                  Veronika
# 9                     Kunde
# 10                 Andre B.
# 11  Käufer Eigentumswohnung
# 12                    Kunde
# 13                    Kunde
# 14                    Kunde
# 15             Christian H.
# 16                    Kunde
# 17            Eduard Brauer
# 18        Lohnstein Dietmar
# 19            Carina Becker
#
#                                                  text  \
# 0   Ich kann Herrn Billor zu 110% nur weiterempfeh...
# 1   Alles top, sehr gute Unterstützung und schnell...
# 2   Unser großes Lob gilt Herrn Frank Pfister, für...
# 3   Wir waren sehr zufrieden mit der Beratung zur ...
# 4   Super Service - besser geht es kaum. Sehr komp...
# 5   Sehr flexible und schnelle Bearbeitung der Anf...
# 6                         Ich bin sehr zufrieden🍷🍷🍷🍾🍾
# 7   Sehr kompetente und freundliche Frau Kihn.Bin ...
# 8   Wir benötigten innerhalb von 1 Woche für einen...
# 9   Wieder gerne. Sehr zufrieden. Besonders...  Be...
# 10  Nichts zu bemängeln.Frau Schröder ist mit sehr...
# 11  Schnelle, kompetente Lösungsvorschläge, gute H...
# 12  Ging recht schnell und unkompliziert.Ohne lang...
# 13  Hat alles bestens mit McMarkler geklappt.  Kan...
# 14  Alles im Allen begann es gut. Maklertermin gin...
# 15                  Top, gut beraten super Abwicklung
# 16
# 17  Wir wurden vom Anfang unserer Anfrage für eine...
# 18  Sehr zufriedenstellende und seriöse Bearbeitun...
# 19  Wir haben unsere Immobilie von Frau Skwarczyns...
#
#                                                 text2
# 0   Ich kann Herrn Billor zu 110% nur weiterempfeh...
# 1   Alles top, sehr gute Unterstützung und schnell...
# 2   Unser großes Lob gilt Herrn Frank Pfister, für...
# 3   Wir waren sehr zufrieden mit der Beratung zur ...
# 4   Super Service - besser geht es kaum. Sehr komp...
# 5   Sehr flexible und schnelle Bearbeitung der Anf...
# 6                         Ich bin sehr zufrieden🍷🍷🍷🍾🍾
# 7   Sehr kompetente und freundliche Frau Kihn.Bin ...
# 8   Wir benötigten innerhalb von 1 Woche für einen...
# 9   Wieder gerne. Sehr zufrieden. Besonders...  Be...
# 10  Nichts zu bemängeln.Frau Schröder ist mit sehr...
# 11  Schnelle, kompetente Lösungsvorschläge, gute H...
# 12  Ging recht schnell und unkompliziert.Ohne lang...
# 13  Hat alles bestens mit McMarkler geklappt.  Kan...
# 14  Alles im Allen begann es gut. Maklertermin gin...
# 15                  Top, gut beraten super Abwicklung
# 16
# 17  Wir wurden vom Anfang unserer Anfrage für eine...
# 18  Sehr zufriedenstellende und seriöse Bearbeitun...
# 19  Wir haben unsere Immobilie von Frau Skwarczyns...
